-- %% [markdown]
-- 9\. FLO tablosundaki master\_id ve order\_channel kolonlarını getiren sorguyu yazınız.

-- %%
SELECT
    master_id,
    order_channel
FROM
    [dbo].[FLO];
-- Out:
-- (19945 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:01.701
-- ...
